# %% [markdown]
# # Bearing Autoencoder — Quotient Operator Experiment
#
# **Goal:** train an autoencoder on *healthy signals only* (with Monte Carlo nuisance).
# The reconstruction error then becomes an implicit membership function for M_healthy.
#
# Architecture: `Conv1D encoder → dense latent → Conv1DTranspose decoder`
#
# Steps:
# 1. Generate MC dataset (healthy train/val + all regimes for test)
# 2. Build and train the autoencoder
# 3. Verify reconstruction fidelity on healthy signals
# 4. Measure reconstruction error across all regimes — this is the anomaly score
# 5. Visualise latent space geometry (PCA of latent vectors)

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from pathlib import Path

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model

np.random.seed(42)
tf.random.set_seed(42)
print('TF version:', tf.__version__)
# Out:
# TF version: 2.16.2

# %% [markdown]
# ## 1. Simulator

# %%
from bearing_simulator import BearingSignalSimulator

# %%
sim = BearingSignalSimulator()
SIG_LEN = len(sim.t)
print(f'Signal length: {SIG_LEN} samples')
# Out:
# Signal length: 1200 samples

# %% [markdown]
# ## 2. Generate dataset
#
# - **Train / Val:** healthy only (MC) — the autoencoder sees only M_healthy
# - **Test:** all four regimes — used only for evaluation, never for training

# %%
REGIMES = ['healthy', 'outer_race', 'inner_race', 'ball_fault']
COLORS  = ['#01696f', '#a12c7b', '#da7101', '#006494']
LABELS  = ['Healthy', 'Outer Race', 'Inner Race', 'Ball Fault']

N_TRAIN  = 800   # healthy train
N_VAL    = 200   # healthy val
N_TEST   = 150   # per regime for test

# ── Healthy train/val ────────────────────────────────────────────────────
X_healthy = np.array([sim.sample('healthy', mc=True) for _ in range(N_TRAIN + N_VAL)])

# Normalise — fit scaler on train only
scaler = StandardScaler()
X_healthy_sc = scaler.fit_transform(X_healthy)

X_train = X_healthy_sc[:N_TRAIN, :, np.newaxis].astype('float32')  # (N, L, 1)
X_val   = X_healthy_sc[N_TRAIN:, :, np.newaxis].astype('float32')

# ── Test set — all regimes ───────────────────────────────────────────────
X_test_list, y_test_list = [], []
for i, regime in enumerate(REGIMES):
    sigs = np.array([sim.sample(regime, mc=True) for _ in range(N_TEST)])
    sigs_sc = scaler.transform(sigs)
    X_test_list.append(sigs_sc)
    y_test_list.extend([i] * N_TEST)

X_test = np.concatenate(X_test_list, axis=0)[:, :, np.newaxis].astype('float32')
y_test = np.array(y_test_list)

print(f'Train: {X_train.shape}  Val: {X_val.shape}  Test: {X_test.shape}')
# Out:
# Train: (800, 1200, 1)  Val: (200, 1200, 1)  Test: (600, 1200, 1)

# %% [markdown]
# ## 3. Autoencoder architecture
#
# ```
# Encoder: Conv1D(32) → Conv1D(64) → Conv1D(128) → Flatten → Dense(latent_dim)
# Decoder: Dense → Reshape → Conv1DTranspose(128) → Conv1DTranspose(64) → Conv1DTranspose(1)
# ```
#
# The latent vector (dim=16) is the quotient representation.
# All convolutional layers use ReLU; the final decoder layer uses linear activation
# to reconstruct the full signal range without clipping.

# %%
LATENT_DIM = 16

def build_autoencoder(sig_len, latent_dim):
    # ── Encoder ──────────────────────────────────────────────────────────
    inp = keras.Input(shape=(sig_len, 1), name='signal_in')
    x = layers.Conv1D(32,  kernel_size=16, strides=2, padding='same', activation='relu')(inp)
    x = layers.Conv1D(64,  kernel_size=8,  strides=2, padding='same', activation='relu')(x)
    x = layers.Conv1D(128, kernel_size=4,  strides=2, padding='same', activation='relu')(x)
    conv_shape = x.shape[1:]            # remember shape before flatten
    x = layers.Flatten()(x)
    latent = layers.Dense(
        latent_dim,
        activity_regularizer=keras.regularizers.l1(1.5e-4),
        name='latent'
    )(x)


    # ── Decoder ──────────────────────────────────────────────────────────
    y = layers.Dense(conv_shape[0] * conv_shape[1], activation='relu')(latent)
    y = layers.Reshape(conv_shape)(y)
    y = layers.Conv1DTranspose(128, kernel_size=4,  strides=2, padding='same', activation='relu')(y)
    y = layers.Conv1DTranspose(64,  kernel_size=8,  strides=2, padding='same', activation='relu')(y)
    y = layers.Conv1DTranspose(32,  kernel_size=16, strides=2, padding='same', activation='relu')(y)
    # Final layer: crop or pad to exact sig_len, linear activation
    y = layers.Conv1D(1, kernel_size=1, padding='same', activation='linear', name='signal_out')(y)
    y = layers.Cropping1D((0, y.shape[1] - sig_len))(y) if y.shape[1] > sig_len else y

    autoencoder = Model(inp, y, name='bearing_autoencoder')
    encoder     = Model(inp, latent, name='encoder')
    return autoencoder, encoder

ae, encoder = build_autoencoder(SIG_LEN, LATENT_DIM)
ae.compile(optimizer=keras.optimizers.Adam(1e-3), loss='mse')
ae.summary()
# Out:
# Model: "bearing_autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ signal_in (InputLayer)          │ (None, 1200, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 600, 32)        │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 300, 64)        │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 150, 128)       │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 19200)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ latent (Dense)                  │ (None, 16)             │       307,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 19200)          │       326,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 150, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_3              │ (None, 300, 128)       │        65,664 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_4              │ (None, 600, 64)        │        65,600 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_transpose_5              │ (None, 1200, 32)       │        32,800 │
# │ (Conv1DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ signal_out (Conv1D)             │ (None, 1200, 1)        │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 847,601 (3.23 MB)
#  Trainable params: 847,601 (3.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 4. Training
#
# Trained on healthy signals only.
# Early stopping on validation loss — prevents overfitting to the training orbit.

# %%
callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)
]

history = ae.fit(
    X_train, X_train,
    validation_data=(X_val, X_val),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)

# Plot training curve
fig, ax = plt.subplots(figsize=(9, 4), facecolor='#f7f6f2')
ax.set_facecolor('#f9f8f5')
ax.plot(history.history['loss'],     label='Train loss', color='#01696f', lw=2)
ax.plot(history.history['val_loss'], label='Val loss',   color='#da7101', lw=2, ls='--')
ax.set_xlabel('Epoch'); ax.set_ylabel('MSE loss')
ax.set_title('Autoencoder training — healthy signals only', fontweight='bold')
ax.legend(); ax.grid(True, alpha=0.25); ax.spines[['top','right']].set_visible(False)
plt.tight_layout(); plt.show()
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.6815 - val_loss: 0.3748 - learning_rate: 0.0010
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.2151 - val_loss: 0.1209 - learning_rate: 0.0010
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.1100 - val_loss: 0.1078 - learning_rate: 0.0010
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0944 - val_loss: 0.0894 - learning_rate: 0.0010
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0853 - val_loss: 0.0819 - learning_rate: 0.0010
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0782 - val_loss: 0.0754 - learning_rate: 0.0010
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0725 - val_loss: 0.0724 - learning_rate: 0.0010
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0705 - val_loss: 0.0715 - learning_rate: 0.0010
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0694 - val_loss: 0.0706 - learning_rate: 0.0010
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0687 - val_loss: 0.0700 - learning_rate: 0.0010
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0682 - val_loss: 0.0694 - learning_rate: 0.0010
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0679 - val_loss: 0.0691 - learning_rate: 0.0010
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0678 - val_loss: 0.0713 - learning_rate: 0.0010
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0737 - val_loss: 0.0740 - learning_rate: 0.0010
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0711 - val_loss: 0.0712 - learning_rate: 0.0010
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0822 - val_loss: 0.0723 - learning_rate: 0.0010
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0703 - val_loss: 0.0696 - learning_rate: 0.0010
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0677 - val_loss: 0.0693 - learning_rate: 5.0000e-04
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0673 - val_loss: 0.0684 - learning_rate: 5.0000e-04
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0665 - val_loss: 0.0681 - learning_rate: 5.0000e-04
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0661 - val_loss: 0.0678 - learning_rate: 5.0000e-04
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0658 - val_loss: 0.0676 - learning_rate: 5.0000e-04
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0655 - val_loss: 0.0676 - learning_rate: 5.0000e-04
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0654 - val_loss: 0.0676 - learning_rate: 5.0000e-04
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0652 - val_loss: 0.0675 - learning_rate: 5.0000e-04
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0650 - val_loss: 0.0674 - learning_rate: 5.0000e-04
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0648 - val_loss: 0.0674 - learning_rate: 5.0000e-04
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0646 - val_loss: 0.0673 - learning_rate: 5.0000e-04
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0644 - val_loss: 0.0672 - learning_rate: 5.0000e-04
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0642 - val_loss: 0.0672 - learning_rate: 5.0000e-04
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0641 - val_loss: 0.0672 - learning_rate: 5.0000e-04
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0639 - val_loss: 0.0672 - learning_rate: 5.0000e-04
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0638 - val_loss: 0.0672 - learning_rate: 5.0000e-04
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0637 - val_loss: 0.0672 - learning_rate: 5.0000e-04
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0644 - val_loss: 0.0677 - learning_rate: 2.5000e-04
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0649 - val_loss: 0.0690 - learning_rate: 2.5000e-04
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0649 - val_loss: 0.0694 - learning_rate: 2.5000e-04
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0650 - val_loss: 0.0683 - learning_rate: 2.5000e-04
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0649 - val_loss: 0.0673 - learning_rate: 2.5000e-04
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0634 - val_loss: 0.0664 - learning_rate: 1.2500e-04
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0629 - val_loss: 0.0664 - learning_rate: 1.2500e-04
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0628 - val_loss: 0.0663 - learning_rate: 1.2500e-04
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0627 - val_loss: 0.0662 - learning_rate: 1.2500e-04
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0626 - val_loss: 0.0661 - learning_rate: 1.2500e-04
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0625 - val_loss: 0.0661 - learning_rate: 1.2500e-04
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0624 - val_loss: 0.0660 - learning_rate: 1.2500e-04
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0623 - val_loss: 0.0660 - learning_rate: 1.2500e-04
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0622 - val_loss: 0.0659 - learning_rate: 1.2500e-04
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0621 - val_loss: 0.0659 - learning_rate: 1.2500e-04
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0620 - val_loss: 0.0658 - learning_rate: 1.2500e-04
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0620 - val_loss: 0.0658 - learning_rate: 1.2500e-04
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0619 - val_loss: 0.0658 - learning_rate: 1.2500e-04
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0618 - val_loss: 0.0657 - learning_rate: 1.2500e-04
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0618 - val_loss: 0.0657 - learning_rate: 1.2500e-04
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0617 - val_loss: 0.0657 - learning_rate: 1.2500e-04
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0616 - val_loss: 0.0656 - learning_rate: 1.2500e-04
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0616 - val_loss: 0.0656 - learning_rate: 1.2500e-04
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0615 - val_loss: 0.0656 - learning_rate: 1.2500e-04
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0615 - val_loss: 0.0656 - learning_rate: 1.2500e-04
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0614 - val_loss: 0.0656 - learning_rate: 1.2500e-04
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0613 - val_loss: 0.0656 - learning_rate: 1.2500e-04
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0616 - val_loss: 0.0673 - learning_rate: 6.2500e-05
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0626 - val_loss: 0.0667 - learning_rate: 6.2500e-05
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0625 - val_loss: 0.0657 - learning_rate: 6.2500e-05
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0619 - val_loss: 0.0655 - learning_rate: 6.2500e-05
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0614 - val_loss: 0.0655 - learning_rate: 6.2500e-05
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0612 - val_loss: 0.0655 - learning_rate: 6.2500e-05
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0612 - val_loss: 0.0655 - learning_rate: 6.2500e-05
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0611 - val_loss: 0.0654 - learning_rate: 6.2500e-05
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0611 - val_loss: 0.0654 - learning_rate: 6.2500e-05
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0609 - val_loss: 0.0654 - learning_rate: 3.1250e-05
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0609 - val_loss: 0.0653 - learning_rate: 3.1250e-05
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0608 - val_loss: 0.0653 - learning_rate: 3.1250e-05
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0608 - val_loss: 0.0653 - learning_rate: 3.1250e-05
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0608 - val_loss: 0.0653 - learning_rate: 3.1250e-05
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0608 - val_loss: 0.0653 - learning_rate: 3.1250e-05
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0608 - val_loss: 0.0653 - learning_rate: 1.5625e-05
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0607 - val_loss: 0.0653 - learning_rate: 1.5625e-05
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0607 - val_loss: 0.0653 - learning_rate: 1.5625e-05
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0607 - val_loss: 0.0653 - learning_rate: 1.5625e-05
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0607 - val_loss: 0.0653 - learning_rate: 1.5625e-05
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0607 - val_loss: 0.0653 - learning_rate: 1.5625e-05
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0607 - val_loss: 0.0653 - learning_rate: 1.5625e-05
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0607 - val_loss: 0.0653 - learning_rate: 1.5625e-05
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0607 - val_loss: 0.0653 - learning_rate: 1.5625e-05
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0607 - val_loss: 0.0653 - learning_rate: 1.5625e-05
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0607 - val_loss: 0.0653 - learning_rate: 1.0000e-05
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0606 - val_loss: 0.0653 - learning_rate: 1.0000e-05
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0606 - val_loss: 0.0653 - learning_rate: 1.0000e-05
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0606 - val_loss: 0.0653 - learning_rate: 1.0000e-05
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0606 - val_loss: 0.0653 - learning_rate: 1.0000e-05
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0606 - val_loss: 0.0653 - learning_rate: 1.0000e-05
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0606 - val_loss: 0.0653 - learning_rate: 1.0000e-05
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0606 - val_loss: 0.0653 - learning_rate: 1.0000e-05
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0606 - val_loss: 0.0652 - learning_rate: 1.0000e-05
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0606 - val_loss: 0.0652 - learning_rate: 1.0000e-05
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0606 - val_loss: 0.0652 - learning_rate: 1.0000e-05
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0606 - val_loss: 0.0652 - learning_rate: 1.0000e-05
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0606 - val_loss: 0.0652 - learning_rate: 1.0000e-05
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0606 - val_loss: 0.0652 - learning_rate: 1.0000e-05

# %% [markdown]
# ## 5. Reconstruction fidelity on healthy signals
#
# Verify the autoencoder faithfully reconstructs the canonical signal
# and MC variants before using reconstruction error as anomaly score.

# %%
# Pick 3 healthy test samples
n_show = 3
samples = X_test[:n_show]          # first N_TEST entries are healthy
recons  = ae.predict(samples, verbose=0)

fig, axes = plt.subplots(n_show, 1, figsize=(13, 8), facecolor='#f7f6f2', sharex=True)
for i, ax in enumerate(axes):
    ax.set_facecolor('#f9f8f5')
    orig = samples[i, :, 0]
    rec  = recons[i, :, 0]
    err  = np.mean((orig - rec)**2)
    ax.plot(orig, color='#01696f', lw=1.2, alpha=0.8, label='Original')
    ax.plot(rec,  color='#da7101', lw=1.2, alpha=0.9, ls='--', label=f'Reconstruction  (MSE={err:.5f})')
    ax.legend(fontsize=9, framealpha=0.7)
    ax.spines[['top','right']].set_visible(False)
    ax.grid(True, alpha=0.2, lw=0.5)
axes[-1].set_xlabel('Sample index')
fig.suptitle('Reconstruction fidelity — healthy signals', fontsize=12, fontweight='bold')
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 6. Reconstruction error as anomaly score
#
# The threshold τ is set at the p95 of healthy reconstruction errors.
# Any signal with error > τ is considered outside M_healthy.
#
# No geometric assumption about the shape of M_healthy is needed —
# the autoencoder encodes it implicitly.

# %%
# Compute per-sample MSE for the full test set
X_test_rec = ae.predict(X_test, verbose=0)
mse = np.mean((X_test - X_test_rec)**2, axis=(1, 2))

# Calibrate threshold on healthy test samples
healthy_mse = mse[y_test == 0]
tau = np.percentile(healthy_mse, 95)
print(f'Threshold τ (p95 healthy MSE) = {tau:.6f}')

# ── Box plot ─────────────────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(9, 5), facecolor='#f7f6f2')
ax.set_facecolor('#f9f8f5')

data_per_regime = [mse[y_test == i] for i in range(4)]
bp = ax.boxplot(data_per_regime, patch_artist=True,
                medianprops=dict(color='white', lw=2),
                whiskerprops=dict(lw=1.2),
                flierprops=dict(marker='o', markersize=3, alpha=0.4))
for patch, color in zip(bp['boxes'], COLORS):
    patch.set_facecolor(color); patch.set_alpha(0.7)

ax.axhline(tau, color='#a12c7b', lw=1.8, ls='--', label=f'τ = {tau:.5f}  (p95 healthy)')
ax.set_xticks(range(1, 5)); ax.set_xticklabels(LABELS, fontsize=10)
ax.set_ylabel('Reconstruction MSE')
ax.set_title('Anomaly score by regime — reconstruction error', fontsize=12, fontweight='bold')
ax.legend(fontsize=10); ax.grid(True, alpha=0.25, axis='y')
ax.spines[['top','right']].set_visible(False)
plt.tight_layout(); plt.show()

# ── Detection rate above τ ───────────────────────────────────────────────
print('\nDetection rate (MSE > τ):')
for i, label in enumerate(LABELS):
    rate = np.mean(mse[y_test == i] > tau)
    print(f'  {label:12s}: {rate:.1%}')
# Out:
# Threshold τ (p95 healthy MSE) = 0.106192
# Detection rate (MSE > τ):
#   Healthy     : 5.3%
#   Outer Race  : 100.0%
#   Inner Race  : 100.0%
#   Ball Fault  : 96.0%

# %% [markdown]
# ## 7. Latent space geometry
#
# PCA of the 16-dimensional latent vectors for all test samples.
#
# Expected result: healthy signals cluster in a compact region.
# Fault regimes deviate — their latent vectors fall outside the healthy orbit.
# This is the learned quotient space in action.

# %%
Z_latent = encoder.predict(X_test, verbose=0)   # (N_test_total, LATENT_DIM)
Z_pca    = PCA(n_components=2).fit_transform(Z_latent)

fig, axes = plt.subplots(1, 2, figsize=(14, 5), facecolor='#f7f6f2')

# Left — PCA scatter
ax = axes[0]
ax.set_facecolor('#f9f8f5')
for i, (color, label) in enumerate(zip(COLORS, LABELS)):
    mask = y_test == i
    ax.scatter(Z_pca[mask, 0], Z_pca[mask, 1],
               c=color, s=22, alpha=0.65, label=label, edgecolors='none')
ax.set_title('Latent space — PCA projection', fontsize=11, fontweight='bold')
ax.set_xlabel('PC1'); ax.set_ylabel('PC2')
ax.legend(fontsize=9, framealpha=0.8, markerscale=1.5)
ax.spines[['top','right']].set_visible(False)
ax.grid(True, alpha=0.2, lw=0.5)

# Right — MSE vs distance to healthy centroid in latent space
ax2 = axes[1]
ax2.set_facecolor('#f9f8f5')
mu_healthy = Z_latent[y_test == 0].mean(axis=0)
dist_to_healthy = np.linalg.norm(Z_latent - mu_healthy, axis=1)
for i, (color, label) in enumerate(zip(COLORS, LABELS)):
    mask = y_test == i
    ax2.scatter(dist_to_healthy[mask], mse[mask],
                c=color, s=22, alpha=0.65, label=label, edgecolors='none')
ax2.axhline(tau, color='#a12c7b', lw=1.5, ls='--', label=f'τ threshold')
ax2.set_xlabel('L2 distance to healthy centroid (latent)')
ax2.set_ylabel('Reconstruction MSE')
ax2.set_title('Latent distance vs reconstruction error', fontsize=11, fontweight='bold')
ax2.legend(fontsize=9, framealpha=0.8, markerscale=1.5)
ax2.spines[['top','right']].set_visible(False)
ax2.grid(True, alpha=0.2, lw=0.5)

plt.tight_layout(); plt.show()

# %% [markdown]
# ## 8. Summary
#
# | What we did | Why it matters for the paper |
# |---|---|
# | Trained autoencoder on healthy MC orbit only | The model learns M_healthy without fault labels |
# | Used reconstruction error as membership function | No geometric assumption about the shape of M_healthy |
# | Calibrated threshold τ at p95 healthy MSE | Principled, data-driven boundary |
# | Visualised latent space | Confirms the latent is a quotient space: healthy collapses, faults separate |
#
# **Next step:** test whether the same latent, trained on simulation, separates regimes
# on real CWRU bearing data — the transfer experiment.

# %%
data_root = Path("CWRU_Bearing_NumPy-main/Data")

def load_1797_normal():
    d = np.load(data_root / "1797 RPM" / "1797_Normal.npz")
    return d["DE"]  # Drive End

def load_1797_ball():
    folder = data_root / "1797 RPM"
    signals = []
    for f in sorted(folder.glob("1797_B_*_DE12.npz")):
        d = np.load(f)
        signals.append(d["DE"])
    return np.concatenate(signals)

def load_1797_inner():
    folder = data_root / "1797 RPM"
    signals = []
    for f in sorted(folder.glob("1797_IR_*_DE12.npz")):
        d = np.load(f)
        signals.append(d["DE"])
    return np.concatenate(signals)

def load_1797_outer():
    folder = data_root / "1797 RPM"
    signals = []
    # Todas las posiciones @3, @6, @12 y severidades
    for f in sorted(folder.glob("1797_OR*@*_DE12.npz")):
        d = np.load(f)
        signals.append(d["DE"])
    return np.concatenate(signals)

normal_1797 = load_1797_normal()
ball_1797   = load_1797_ball()
inner_1797  = load_1797_inner()
outer_1797  = load_1797_outer()

print("Normal:", normal_1797.shape)
print("Ball:  ", ball_1797.shape)
print("Inner: ", inner_1797.shape)
print("Outer: ", outer_1797.shape)
# Out:
# Normal: (243938, 1)
# Ball:   (487209, 1)
# Inner:  (486048, 1)
# Outer:  (854372, 1)

# %%
def make_windows(x, win=1200, step=1200):
    n = (len(x) - win) // step + 1
    return np.stack([x[i*step:i*step+win] for i in range(n)], axis=0)

# %%
ws_cwru = make_windows(normal_1797, win=1200, step=1200)  # como MC
ws_cwru_2d = ws_cwru.reshape(ws_cwru.shape[0], -1)
ws_cwru_sc = scaler.transform(ws_cwru_2d)

X_cwru = ws_cwru_sc[:, :, np.newaxis].astype('float32')
x_cwru_rec = ae.predict(X_cwru, verbose=0)
mse_cwru = np.mean((X_cwru - x_cwru_rec)**2, axis=(1, 2))

# Recompute τ_MC for sim data
X_healthy_rec = ae.predict(X_train, verbose=0)
mse_mc_healthy = np.mean((X_train - X_healthy_rec)**2, axis=(1, 2))
tau_mc = np.percentile(mse_mc_healthy, 95)
tau_cwru_healthy = np.percentile(mse_cwru, 95)

print(f"τ_MC = {tau_mc:.6f}")
print(f"τ_CWRU = {tau_cwru_healthy:.6f}")
# Out:
# τ_MC = 0.093217
# τ_CWRU = 0.263624

# %%
plt.figure(figsize=(21, 8))
plt.plot(X_cwru[100])
plt.plot(x_cwru_rec[100]);

# %% [markdown]
# ### BLUEPRINT LEARNING

# %% [markdown]
# ##### ADAPTIVE TAU

# %%
from collections import deque

# %%
class AdaptiveTau:
    def __init__(self, z_mc, window_size=500):
        self.z_mc = z_mc
        self.window_size = window_size
        self.buf = deque(maxlen=window_size)

    def update(self, mse_value):
        self.buf.append(float(mse_value))
        arr = np.array(self.buf)
        mu = arr.mean()
        sigma = arr.std() if len(arr) > 1 else 0.0
        tau = mu + self.z_mc * sigma
        return mu, sigma, tau

# %%
# ── Compute CWRU MSEs first ─────────────────────────────────────────────
def cwru_mse(signal_1d):
    ws    = make_windows(signal_1d, win=1200, step=1200)
    ws_2d = ws.reshape(ws.shape[0], -1)
    ws_sc = scaler.transform(ws_2d)
    X     = ws_sc[:, :, np.newaxis].astype('float32')
    X_rec = ae.predict(X, verbose=0)
    return np.mean((X - X_rec)**2, axis=(1, 2))

# %%
mse_cwru_healthy = cwru_mse(normal_1797)
mse_cwru_ball    = cwru_mse(ball_1797)
mse_cwru_inner   = cwru_mse(inner_1797)
mse_cwru_outer   = cwru_mse(outer_1797)

print(f"Windows → healthy:{len(mse_cwru_healthy)} ball:{len(mse_cwru_ball)} inner:{len(mse_cwru_inner)} outer:{len(mse_cwru_outer)}")
# Out:
# Windows → healthy:203 ball:406 inner:405 outer:711

# %%
mu_cwru  = mse_cwru_healthy.mean()
std_cwru = mse_cwru_healthy.std()

# τ puente: mismo z_mc trasladado al espacio de campo
tau_bridge = mu_cwru + z_mc * std_cwru

# τ campo puro: p95 sobre healthy CWRU (referencia)
tau_campo_p95 = np.percentile(mse_cwru_healthy, 95)

print(f"Campo    → mu={mu_cwru:.4f}, std={std_cwru:.4f}")
print(f"τ_bridge = {tau_bridge:.4f}")
print(f"τ_campo p95 = {tau_campo_p95:.4f}")

# ── 3) Arrancar la ventana adaptativa con healthy CWRU ─────────────────
adaptive = AdaptiveTau(z_mc=z_mc, window_size=500)

for mse_val in mse_cwru_healthy:
    mu_t, sigma_t, tau_t = adaptive.update(mse_val)

print(f"\nτ_adaptativo (tras warm-up con healthy CWRU) = {tau_t:.4f}")
print(f"  mu_t={mu_t:.4f}, sigma_t={sigma_t:.4f}")

# ── 4) Detection rates para los tres τ ─────────────────────────────────
def detection_rate(mse, tau):
    return np.mean(mse > tau) * 100.0

print("\n── Detection rates (MSE > τ) ──────────────────────────────")
print(f"{'Régimen':<12} {'τ_MC':>8} {'τ_bridge':>10} {'τ_p95_campo':>13} {'τ_adapt':>10}")
print("-" * 55)

for name, mse in [("Healthy",  mse_cwru_healthy),
                  ("Ball",     mse_cwru_ball),
                  ("Inner",    mse_cwru_inner),
                  ("Outer",    mse_cwru_outer)]:
    dr_mc     = detection_rate(mse, tau_mc)
    dr_bridge = detection_rate(mse, tau_bridge)
    dr_p95    = detection_rate(mse, tau_campo_p95)
    dr_adapt  = detection_rate(mse, tau_t)
    print(f"{name:<12} {dr_mc:>7.1f}% {dr_bridge:>9.1f}% {dr_p95:>12.1f}% {dr_adapt:>9.1f}%")
# Out:
# Campo    → mu=0.2270, std=0.0215
# τ_bridge = 0.2543
# τ_campo p95 = 0.2636
#
# τ_adaptativo (tras warm-up con healthy CWRU) = 0.2543
#   mu_t=0.2270, sigma_t=0.0215
#
# ── Detection rates (MSE > τ) ──────────────────────────────
# Régimen          τ_MC   τ_bridge   τ_p95_campo    τ_adapt
# -------------------------------------------------------
# Healthy        100.0%      11.8%          5.4%      11.8%
# Ball           100.0%      99.0%         98.3%      99.0%
# Inner          100.0%     100.0%        100.0%     100.0%
# Outer          100.0%     100.0%        100.0%     100.0%

# %%
mse_mean = mse_cwru_healthy.mean()
mse_std  = mse_cwru_healthy.std()
p95      = np.percentile(mse_cwru_healthy, 95)
p99      = np.percentile(mse_cwru_healthy, 99)

fig, ax = plt.subplots(figsize=(10, 5))

ax.hist(mse_cwru_healthy, bins=50, density=True, alpha=0.6, color='steelblue', label='Healthy CWRU')

ax.axvline(tau_mc,          color='red',    linestyle='--', lw=1.5, label=f'τ_MC       = {tau_mc:.4f}')
ax.axvline(tau_bridge,      color='orange', linestyle='--', lw=1.5, label=f'τ_bridge   = {tau_bridge:.4f}')
ax.axvline(tau_campo_p95,   color='green',  linestyle='--', lw=1.5, label=f'τ_p95_field= {tau_campo_p95:.4f}')
ax.axvline(tau_t,           color='purple', linestyle='--', lw=1.5, label=f'τ_adaptive = {tau_t:.4f}')

ax.set_xlabel("MSE")
ax.set_ylabel("Density")
ax.set_title("MSE Distribution — Healthy CWRU in Q")
ax.legend()
plt.tight_layout()
plt.show()

print(f"Healthy CWRU → mean={mse_mean:.4f}, std={mse_std:.4f}, p95={p95:.4f}, p99={p99:.4f}")
# Out:
# Healthy CWRU → mean=0.2270, std=0.0215, p95=0.2636, p99=0.2753

# %%
fig, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)

adaptive_plot = AdaptiveTau(z_mc=z_mc, window_size=500)

history_tau   = []
history_mu    = []
history_sigma = []

for mse_val in mse_cwru_healthy:
    mu_t, sigma_t, tau_t = adaptive_plot.update(mse_val)
    history_tau.append(tau_t)
    history_mu.append(mu_t)
    history_sigma.append(sigma_t)

steps = range(len(history_tau))

# ── τ convergence ──────────────────────────────────────────────
axes[0].plot(steps, history_tau, color='purple', lw=1.5, label='τ_adaptive')
axes[0].axhline(tau_bridge,    color='orange', linestyle='--', lw=1.2, label=f'τ_bridge = {tau_bridge:.4f}')
axes[0].axhline(tau_campo_p95, color='green',  linestyle='--', lw=1.2, label=f'τ_p95    = {tau_campo_p95:.4f}')
axes[0].axvline(500, color='gray', linestyle=':', lw=1, label='window full')
axes[0].set_ylabel("τ")
axes[0].set_title("Adaptive τ convergence — Healthy CWRU cold start")
axes[0].legend(fontsize=8)

# ── mu convergence ─────────────────────────────────────────────
axes[1].plot(steps, history_mu, color='steelblue', lw=1.5)
axes[1].axhline(mu_cwru, color='steelblue', linestyle='--', lw=1.2, label=f'final mu = {mu_cwru:.4f}')
axes[1].set_ylabel("μ (mean MSE)")
axes[1].legend(fontsize=8)

# ── sigma convergence ──────────────────────────────────────────
axes[2].plot(steps, history_sigma, color='coral', lw=1.5)
axes[2].axhline(std_cwru, color='coral', linestyle='--', lw=1.2, label=f'final σ = {std_cwru:.4f}')
axes[2].set_ylabel("σ (std MSE)")
axes[2].set_xlabel("Window (samples)")
axes[2].legend(fontsize=8)

plt.tight_layout()
plt.show()
